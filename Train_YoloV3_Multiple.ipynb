# %% [markdown]
# # ODN AI INTERN PROJECT

# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Sat Feb 27 10:59:19 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Cognizant Interview.gdoc'
# 'Colab Notebooks'
# 'Course 1n2 completion certificate.pdf'
# 'Course 3n4 completion certificate.pdf'
# 'Degree BE.pdf'
# 'IBM certificate.pdf'
#  IMG-20180724-WA0001.jpg
# 'J. K. Rowling - Harry Potter and the Sorcerer'\''s Stone (1999).pdf'
# 'Krishna flute player.mp3'
# 'My Drive'
# 'Peer Evaluation Links .gdoc'
# 'PRO Letter.pdf'
#  Resume
# 'Task Links!!.gdoc'
# 'Task Links.gdoc'
# 'Vaishnodevi Soundtracks 02 - Sansar Ka Sanchar Hai Song.mp3'
# 'Weapons Detection'
#  yolov3
#  yolov3-proj2

# %% [markdown]
# **1) Clone, configure & compile Darknet**

# %%
# Clone
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14691, done.
# remote: Total 14691 (delta 0), reused 0 (delta 0), pack-reused 14691
# Receiving objects: 100% (14691/14691), 13.27 MiB | 25.54 MiB/s, done.
# Resolving deltas: 100% (9995/9995), done.

# %%
# Configure
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# Compile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# **2) Configure yolov3.cfg file**

# %%
# Make a copy of yolov3.cfg
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# Change lines in yolov3.cfg file
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=21@' cfg/yolov3_training.cfg

# %% [markdown]
# **3) Create .names and .data files**

# %%
# !echo -e 'shirt\nsneaker' > data/obj.names
# !echo -e 'classes= 2\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3-proj2' > data/obj.data

# %% [markdown]
# **4) Save yolov3_training.cfg and obj.names files in Google drive**

# %%
# !cp cfg/yolov3_training.cfg /mydrive/yolov3-proj2/yolov3_testing.cfg
# !cp data/obj.names /mydrive/yolov3-proj2/classes.txt

# %% [markdown]
# **5) Create a folder and unzip image dataset**

# %%
# !mkdir data/obj
# !unzip /mydrive/yolov3-proj2/images.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov3-proj2/images.zip
#  extracting: data/obj/classes.txt
#   inflating: data/obj/idris-elba-polo-shirt.jpg
#   inflating: data/obj/idris-elba-polo-shirt.txt
#   inflating: data/obj/image (2).jpeg
#   inflating: data/obj/image (2).txt
#   inflating: data/obj/image.jpeg
#   inflating: data/obj/image.txt
#   inflating: data/obj/image0 (2).jpeg
#   inflating: data/obj/image0 (2).txt
#   inflating: data/obj/image0.jpeg
#   inflating: data/obj/image0.txt
#   inflating: data/obj/image1.jpeg
#   inflating: data/obj/image1.txt
#   inflating: data/obj/image10.jpeg
#   inflating: data/obj/image10.txt
#   inflating: data/obj/image11.jpeg
#   inflating: data/obj/image11.txt
#   inflating: data/obj/image12.jpeg
#   inflating: data/obj/image12.txt
#   inflating: data/obj/image13.jpeg
#   inflating: data/obj/image13.txt
#   inflating: data/obj/image14.jpeg
#   inflating: data/obj/image14.txt
#   inflating: data/obj/image15 (2).jpeg
#   inflating: data/obj/image15 (2).txt
# ...

# %% [markdown]
# **6) Create train.txt file**

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
with open("data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %% [markdown]
# **7) Download pre-trained weights for the convolutional layers file**

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-02-27 11:02:11--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  42.6MB/s    in 4.0s
#
# 2021-02-27 11:02:15 (38.5 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# **8) Start training**

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Uncomment below and comment above to re-start your training from last saved weights
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg /mydrive/yolov3-proj2/yolov3_training_last.weights -dont_show
# Out:
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.852243), count: 8, class_loss = 0.145359, iou_loss = 0.158285, total_loss = 0.303644
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000935, iou_loss = 0.000000, total_loss = 0.000935
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 272761, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.876418), count: 5, class_loss = 0.000591, iou_loss = 0.038832, total_loss = 0.039422
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...
